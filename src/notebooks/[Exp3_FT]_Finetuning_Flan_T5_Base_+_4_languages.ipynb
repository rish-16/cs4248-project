# %%
# !pip install evaluate Pillow==9.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 4.1 MB/s eta 0:00:00
# Collecting Pillow==9.0.0
#   Downloading Pillow-9.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2023.3.0)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 30.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from evaluate) (23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.4.4)
# Collecting huggingface-hub>=0.7.0
#   Downloading huggingface_hub-0.13.3-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 28.3 MB/s eta 0:00:00
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.27.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.22.4)
# Collecting dill
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 19.5 MB/s eta 0:00:00
# Collecting datasets>=2.0.0
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 81.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.10.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2022.7.1)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 36.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 24.5 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Installing collected packages: xxhash, Pillow, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets, evaluate
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
# Successfully installed Pillow-9.0.0 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 evaluate-0.4.0 frozenlist-1.3.3 huggingface-hub-0.13.3 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %%
# !pip install pytesseract transformers datasets rouge-score nltk tensorboard py7zr --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Collecting tensorboard
#   Downloading tensorboard-2.12.1-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 102.8 MB/s eta 0:00:00
# Collecting py7zr
#   Downloading py7zr-0.20.4-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 KB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from pytesseract) (9.0.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.9/dist-packages (from pytesseract) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 108.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (2.2.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (1.53.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (2.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (3.4.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (67.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard) (1.8.1)
# Collecting pyppmd<1.1.0,>=0.18.1
#   Downloading pyppmd-1.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 KB 22.2 MB/s eta 0:00:00
# Collecting brotli>=1.0.9
#   Downloading Brotli-1.0.9-cp39-cp39-manylinux1_x86_64.whl (357 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.2/357.2 KB 44.3 MB/s eta 0:00:00
# Collecting pycryptodomex>=3.6.6
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 96.6 MB/s eta 0:00:00
# Collecting inflate64>=0.3.1
#   Downloading inflate64-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 KB 13.2 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4
#   Downloading pyzstd-0.15.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.0/384.0 KB 43.9 MB/s eta 0:00:00
# Collecting texttable
#   Downloading texttable-1.6.7-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from py7zr) (5.9.4)
# Collecting pybcj>=0.6.0
#   Downloading pybcj-1.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 KB 8.0 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard) (6.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard) (3.2.2)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=514b93ab3b433379cccfa560ee5f02152c06873bb00fd94a1a5f9a9dd41610a6
#   Stored in directory: /root/.cache/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge-score
# Installing collected packages: tokenizers, texttable, brotli, pyzstd, pytesseract, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, rouge-score, py7zr, transformers, google-auth-oauthlib, tensorboard
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 0.4.6
#     Uninstalling google-auth-oauthlib-0.4.6:
#       Successfully uninstalled google-auth-oauthlib-0.4.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.0
#     Uninstalling tensorboard-2.12.0:
#       Successfully uninstalled tensorboard-2.12.0
# Successfully installed brotli-1.0.9 google-auth-oauthlib-1.0.0 inflate64-0.3.1 multivolumefile-0.2.3 py7zr-0.20.4 pybcj-1.0.1 pycryptodomex-3.17 pyppmd-1.0.0 pytesseract-0.3.10 pyzstd-0.15.4 rouge-score-0.1.2 tensorboard-2.12.1 texttable-1.6.7 tokenizers-0.13.2 transformers-4.27.4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
DATAPATH = "drive/MyDrive/CS4248 Team 19/translated_data/"

# %%
import pandas as pd

def read_translated_data(path, n_samples, lang):
    """
    0: premise
    1: hypothesis
    2: label
    3: explanation
    """
    df = pd.read_csv(path)
    premise = df['premise'].values.tolist()[:n_samples]
    hypo = df['hypothesis'].values.tolist()[:n_samples]
    label = df['label'].values.tolist()[:n_samples]
    expl = df['explanation_1'].values.tolist()[:n_samples]
    langs = [lang for _ in range(n_samples)]
    data = list(zip(premise, hypo, label, expl, langs))
    return data

# %%
n_samples_per_lang = 5000 # change accordingly based on performance

languages = {
    "german": read_translated_data(f"{DATAPATH}esnli_train_de.csv", n_samples_per_lang, "german"),
    "english": read_translated_data(f"{DATAPATH}esnli_train_en.csv", n_samples_per_lang, "english"),
    "spanish": read_translated_data(f"{DATAPATH}esnli_train_es.csv", n_samples_per_lang, "spanish"),
    "french": read_translated_data(f"{DATAPATH}esnli_train_fr.csv", n_samples_per_lang, "french"),
    "dutch": read_translated_data(f"{DATAPATH}esnli_train_nl.csv", n_samples_per_lang, "dutch"),
}

# %%
from pprint import pprint
from random import randrange

idx = randrange(len(languages['english']))
pprint (languages['english'][idx])
print ()
pprint (languages['spanish'][idx])
# Out:
# ('People enjoying the sandy beach near the water with a funny looking tree on '
#  'the beach.',
#  'the people are flying a plane',
#  'contradiction',
#  "The people can't be enjoying a sandy beach and flying a plane at the same "
#  'time.',
#  'english')
#
# ('Gente disfrutando de la playa de arena cerca del agua con un árbol de '
#  'aspecto divertido en la playa.',
#  'la gente está volando un avión',
#  'contradiction',
#  'La gente no puede disfrutar de una playa de arena y volar un avión al mismo '
#  'tiempo.',
#  'spanish')

# %%
final_train_categories = {
    "english": True,
    "spanish": True,
    "french": True,
    "dutch": True,
    "german": False
}
final_train_dataset = []
for lang, choice in final_train_categories.items():
    if choice:
        final_train_dataset.extend(languages[lang])

print ("Number of training samples:", len(final_train_dataset))
assert len(final_train_dataset) % n_samples_per_lang == 0, "Dataset sample mismatch error"

final_test_categories = {
    "english": False,
    "spanish": False,
    "french": False,
    "dutch": False,
    "german": True
}
final_test_dataset = []
for lang, choice in final_test_categories.items():
    if choice:
        final_test_dataset.extend(languages[lang])

print ("Number of testing samples:", len(final_test_dataset))
assert len(final_test_dataset) % n_samples_per_lang == 0, "Dataset sample mismatch error"
# Out:
# Number of training samples: 20000
# Number of testing samples: 5000

# %%
final_train_dataset_df = pd.DataFrame(data=final_train_dataset, columns=["premise", "hypothesis", "label", "explanation_1", "language"])
final_test_dataset_df = pd.DataFrame(data=final_test_dataset, columns=["premise", "hypothesis", "label", "explanation_1", "language"])

# %% [markdown]
# For a given `premise` and `hypothesis`, the input is structured as follows:
#
# ```plaintext
# Premise: <premise>. Hypothesis: <hypothesis>
# ```
#
# and the output is structured as follows:
#
# ```plaintext
# <label>. <explanation>.
# ```
#
# An example:
#
# **INPUT:**
# "Premise: A person on a horse jumps over a broken down airplane. Hypothesis: A person is training his horse for a competition. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined."
#
# **OUTPUT:**
# "Neutral. The person is not necessarily training his horse."

# %%
final_train_dataset_df['combined_premhypo'] = "Premise: " + final_train_dataset_df['premise'] + " Hypothesis: " + final_train_dataset_df['hypothesis']
final_test_dataset_df['combined_premhypo'] = "Premise: " + final_test_dataset_df['premise'] + " Hypothesis: " + final_test_dataset_df['hypothesis']

final_train_dataset_df['combined_target'] = final_train_dataset_df['label'].str.title() + ". " + final_train_dataset_df['explanation_1'].str.title()
final_test_dataset_df['combined_target'] = final_test_dataset_df['label'].str.title() + ". " + final_test_dataset_df['explanation_1'].str.title()

# %%
# print (final_train_dataset_df.values.tolist()[0][0])
print ("input:", final_train_dataset_df.values.tolist()[0][-2])
print ("output:", final_train_dataset_df.values.tolist()[0][-1])

print ("input:", final_train_dataset_df.values.tolist()[-1][-2])
print ("output:", final_train_dataset_df.values.tolist()[-1][-1])
# Out:
# input: Premise: A person on a horse jumps over a broken down airplane. Hypothesis: A person is training his horse for a competition.
# output: Neutral. The Person Is Not Necessarily Training His Horse
# input: Premise: Iemand rijdt zijwaarts op een motorfiets. Hypothesis: Een kind leert gewoon een motorfiets te rijden, en weet niet goed hoe hij moet monteren.
# output: Neutral. We Kunnen Niet Afleiden Wie Iemand Is, Zin Twee Vertelt Ons Dat Het Een Onervaren Kind Is. Niet Alle Mensen Die Zijwaarts Rijden Weten Niet Hoe Ze Moeten Klimmen Of Leren.

# %%
from datasets import Dataset

final_train_dataset_hf = Dataset.from_pandas(final_train_dataset_df)
final_test_dataset_hf = Dataset.from_pandas(final_test_dataset_df)

# %%
from datasets import DatasetDict

dataset = DatasetDict({"train": final_train_dataset_hf, "test": final_test_dataset_hf})

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

model_id = "google/flan-t5-base" # ryan: change to flan-t5-large
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
from datasets import concatenate_datasets

tokenised_inputs = concatenate_datasets([
    dataset['train'],
    dataset['test'],
]).map(lambda x : tokenizer(x['combined_premhypo'], truncation=True), batched=True, remove_columns=["combined_premhypo", "premise", "hypothesis", "combined_target"])

max_source_length = max([len(x) for x in tokenised_inputs["input_ids"]])
print(f"Max source length: {max_source_length}")

tokenized_targets = concatenate_datasets([
    dataset['train'],
    dataset['test'],
]).map(lambda x: tokenizer(x["combined_target"], truncation=True), batched=True, remove_columns=["combined_premhypo", "premise", "hypothesis", "combined_target"])

max_target_length = max([len(x) for x in tokenized_targets["input_ids"]])
print(f"Max target length: {max_target_length}")
# Out:
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Max source length: 349
# Map:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Max target length: 386

# %%
def preprocess(sample, padding="max_length"):
    def create_prompt(exg):
        item, lang = exg
        # if lang == "english":
        #     prompt = f"""{item} Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined."""
        # elif lang == "french":
        #     prompt = f"""{item} Veuillez fournir une justification indiquant si l'hypothèse est impliquée par la prémisse, contredite par la prémisse ou si elle ne peut pas être déterminée."""
        # elif lang == "dutch":
        #     prompt = f"""{item} Geef een rechtvaardiging voor de vraag of de hypothese wordt veroorzaakt door de premisse, wordt tegengesproken door de premisse, of dat deze niet kan worden bepaald."""
        # elif lang == "spanish":
        #     prompt = f"""{item} Proporcione una justificación de si la premisa implica la hipótesis, si la premisa la contradice o si no se puede determinar."""
        # elif lang == "german":
        #     prompt = f"""{item} Bitte begründen Sie, ob die Hypothese durch die Prämisse bedingt ist, durch die Prämisse widerlegt wird oder nicht festgestellt werden kann."""
        prompt = f"""{item} Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined."""
        return prompt

    inputs = [create_prompt(item) for item in zip(sample['combined_premhypo'], sample['language'])]
    print (inputs[:5])

    # tokenize inputs
    model_inputs = tokenizer(inputs, max_length=max_source_length, padding=padding, truncation=True)

    # Tokenize targets with the `text_target` keyword argument
    labels = tokenizer(text_target=sample["combined_target"], max_length=max_target_length, padding=padding, truncation=True)

    # If we are padding here, replace all tokenizer.pad_token_id in the labels by -100 when we want to ignore
    # padding in the loss.
    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
        ]

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenized_dataset = dataset.map(preprocess, batched=True, remove_columns=["premise", "hypothesis", "combined_premhypo", "combined_target", "label"])
print(f"Keys of tokenized dataset: {list(tokenized_dataset['train'].features)}")
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# ['Premise: A person on a horse jumps over a broken down airplane. Hypothesis: A person is training his horse for a competition. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A person on a horse jumps over a broken down airplane. Hypothesis: A person is at a diner, ordering an omelette. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A person on a horse jumps over a broken down airplane. Hypothesis: A person is outdoors, on a horse. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Children smiling and waving at camera Hypothesis: They are smiling at their parents Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Children smiling and waving at camera Hypothesis: There are children present Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Small laughing child with blond-hair sitting at a table holding a green sippy cup. Hypothesis: The child is happy. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Small laughing child with blond-hair sitting at a table holding a green sippy cup. Hypothesis: A child is drinking apple juice. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Small laughing child with blond-hair sitting at a table holding a green sippy cup. Hypothesis: A child is throwing a tantrum. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A little boy drinks milk and gets milk all over his face and table. Hypothesis: the kid has milk on his face on a school day Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A little boy drinks milk and gets milk all over his face and table. Hypothesis: the dog eats mice Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Two women standing under an umbrella. Hypothesis: two guys walking in the rain Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: a brown dog is jumping up at a woman who is wearing a brown skirt. Hypothesis: The dog sees his owner after a few hours. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: a brown dog is jumping up at a woman who is wearing a brown skirt. Hypothesis: A dog is being friendly. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: a brown dog is jumping up at a woman who is wearing a brown skirt. Hypothesis: A dog attacks a man. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: One dog is jumping at the lady while the other walks away. Hypothesis: Two dogs are sleeping next to the lady. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: A little girl smiling in a colorful knitted hat. Hypothesis: The little girl is happy Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Little girl wearing a colorful hat while propped up on a cushion. Hypothesis: A little girl runs through the living room laughing Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Little girl wearing a colorful hat while propped up on a cushion. Hypothesis: A little girl is inside. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Little girl wearing a colorful hat while propped up on a cushion. Hypothesis: A child sits for her first birthday photos Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Little girl wearing a colorful hat while propped up on a cushion. Hypothesis: A little girl wears a colorful hat. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: A boy is going down the slide. Hypothesis: A boy is on a slide Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A boy is going down the slide. Hypothesis: A boy is at the park Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A boy is going down the slide. Hypothesis: A boy is in a tent Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A gray terrier runs in a snow-covered field. Hypothesis: A gray dog running outdoors. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: A gray terrier runs in a snow-covered field. Hypothesis: A gray dog chasing a squirrel outdoors. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Una persona en un caballo salta sobre un avión derribado. Hypothesis: Una persona está entrenando a su caballo para una competición. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Una persona en un caballo salta sobre un avión derribado. Hypothesis: Una persona está en un restaurante, pidiendo una tortilla. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Una persona en un caballo salta sobre un avión derribado. Hypothesis: Una persona está al aire libre, en un caballo. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niños sonriendo y saludando a la cámara Hypothesis: Están sonriendo a sus padres. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niños sonriendo y saludando a la cámara Hypothesis: Hay niños presentes Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Pequeño niño risueño de pelo rubio sentado en una mesa con una taza verde. Hypothesis: El niño es feliz. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Pequeño niño risueño de pelo rubio sentado en una mesa con una taza verde. Hypothesis: Un niño está bebiendo jugo de manzana. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Pequeño niño risueño de pelo rubio sentado en una mesa con una taza verde. Hypothesis: Un niño está lanzando una rabieta. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un niño pequeño bebe leche y se pone leche por toda la cara y la mesa. Hypothesis: el niño tiene leche en la cara en un día de escuela Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un niño pequeño bebe leche y se pone leche por toda la cara y la mesa. Hypothesis: el perro come ratones Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Dos mujeres de pie bajo un paraguas. Hypothesis: dos tipos caminando bajo la lluvia Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un perro marrón está saltando a una mujer que lleva una falda marrón. Hypothesis: El perro ve a su dueño después de unas horas. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un perro marrón está saltando a una mujer que lleva una falda marrón. Hypothesis: Un perro está siendo amable. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un perro marrón está saltando a una mujer que lleva una falda marrón. Hypothesis: Un perro ataca a un hombre. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un perro está saltando a la dama mientras que el otro se va. Hypothesis: Dos perros duermen al lado de la señora. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Una niña sonriente en un colorido sombrero de punto. Hypothesis: La niña es feliz. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niña que lleva un sombrero colorido mientras se apoya en un cojín. Hypothesis: Una niña corre por la sala de estar riéndose Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niña que lleva un sombrero colorido mientras se apoya en un cojín. Hypothesis: Una niña está dentro. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niña que lleva un sombrero colorido mientras se apoya en un cojín. Hypothesis: Un niño se sienta para sus fotos de primer cumpleaños Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Niña que lleva un sombrero colorido mientras se apoya en un cojín. Hypothesis: Una niña lleva un sombrero colorido. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Un chico está bajando por el tobogán. Hypothesis: Un chico está en un tobogán. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un chico está bajando por el tobogán. Hypothesis: Un chico está en el parque. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un chico está bajando por el tobogán. Hypothesis: Un chico está en una tienda. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un terrier gris corre en un campo cubierto de nieve. Hypothesis: Un perro gris corriendo al aire libre. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un terrier gris corre en un campo cubierto de nieve. Hypothesis: Un perro gris persiguiendo a una ardilla al aire libre. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ["Premise: Une personne sur un cheval saute au-dessus d'un avion brisé. Hypothesis: Une personne forme son cheval pour une compétition. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", "Premise: Une personne sur un cheval saute au-dessus d'un avion brisé. Hypothesis: Une personne est dans un restaurant, en train de commander une omelette. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", "Premise: Une personne sur un cheval saute au-dessus d'un avion brisé. Hypothesis: Une personne est à l'extérieur, sur un cheval. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", 'Premise: Enfants souriant et agitant à la caméra Hypothesis: Ils sourient à leurs parents. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Enfants souriant et agitant à la caméra Hypothesis: Il y a des enfants présents. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ["Premise: Petit enfant riant avec cheveux blonds assis à une table tenant une tasse verte sippy. Hypothesis: L'enfant est heureux. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", 'Premise: Petit enfant riant avec cheveux blonds assis à une table tenant une tasse verte sippy. Hypothesis: Un enfant boit du jus de pomme. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', "Premise: Petit enfant riant avec cheveux blonds assis à une table tenant une tasse verte sippy. Hypothesis: Un enfant s'en prend à lui. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", "Premise: Un petit garçon boit du lait et reçoit du lait sur son visage et sa table. Hypothesis: Le gamin a du lait sur le visage le jour de l'école. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", 'Premise: Un petit garçon boit du lait et reçoit du lait sur son visage et sa table. Hypothesis: le chien mange des souris Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Deux femmes debout sous un parapluie. Hypothesis: deux gars qui marchent sous la pluie Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: un chien brun saute sur une femme qui porte une jupe brune. Hypothesis: Le chien voit son propriétaire après quelques heures. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: un chien brun saute sur une femme qui porte une jupe brune. Hypothesis: Un chien est amical. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: un chien brun saute sur une femme qui porte une jupe brune. Hypothesis: Un chien attaque un homme. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', "Premise: Un chien saute sur la dame tandis que l'autre s'en va. Hypothesis: Deux chiens dorment à côté de la dame. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined."]
# ['Premise: Une petite fille souriant dans un chapeau tricoté coloré. Hypothesis: La petite fille est heureuse Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Petite fille portant un chapeau coloré tout en montant sur un coussin. Hypothesis: Une petite fille traverse le salon en riant Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', "Premise: Petite fille portant un chapeau coloré tout en montant sur un coussin. Hypothesis: Une petite fille est à l'intérieur. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", "Premise: Petite fille portant un chapeau coloré tout en montant sur un coussin. Hypothesis: Un enfant est assis pour ses premières photos d'anniversaire Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", 'Premise: Petite fille portant un chapeau coloré tout en montant sur un coussin. Hypothesis: Une petite fille porte un chapeau coloré. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Un garçon descend la diapositive. Hypothesis: Un garçon est sur un toboggan Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un garçon descend la diapositive. Hypothesis: Un garçon est au parc. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un garçon descend la diapositive. Hypothesis: Un garçon est dans une tente Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Un terrier gris coule dans un champ enneigé. Hypothesis: Un chien gris qui court dehors. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', "Premise: Un terrier gris coule dans un champ enneigé. Hypothesis: Un chien gris pourchassant un écureuil à l'extérieur. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined."]
# ['Premise: Een persoon op een paard springt over een kapot vliegtuig. Hypothesis: Iemand traint zijn paard voor een wedstrijd. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een persoon op een paard springt over een kapot vliegtuig. Hypothesis: Een persoon is in een eetcafé, bestelt een omelet. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een persoon op een paard springt over een kapot vliegtuig. Hypothesis: Een persoon is buiten, op een paard. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kinderen lachen en zwaaien naar de camera Hypothesis: Ze lachen naar hun ouders. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kinderen lachen en zwaaien naar de camera Hypothesis: Er zijn kinderen aanwezig Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Klein lachend kind met blond haar zittend aan een tafel met een groene sippy beker. Hypothesis: Het kind is gelukkig. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Klein lachend kind met blond haar zittend aan een tafel met een groene sippy beker. Hypothesis: Een kind drinkt appelsap. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Klein lachend kind met blond haar zittend aan een tafel met een groene sippy beker. Hypothesis: Een kind heeft een driftbui. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een kleine jongen drinkt melk en krijgt melk over zijn gezicht en tafel. Hypothesis: de jongen heeft melk op zijn gezicht op een schooldag Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een kleine jongen drinkt melk en krijgt melk over zijn gezicht en tafel. Hypothesis: de hond eet muizen Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Twee vrouwen die onder een paraplu staan. Hypothesis: twee mannen lopen in de regen Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een bruine hond springt op naar een vrouw die een bruine rok draagt. Hypothesis: De hond ziet zijn eigenaar na een paar uur. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een bruine hond springt op naar een vrouw die een bruine rok draagt. Hypothesis: Een hond is vriendelijk. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een bruine hond springt op naar een vrouw die een bruine rok draagt. Hypothesis: Een hond valt een man aan. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: De ene hond springt naar de dame terwijl de andere wegloopt. Hypothesis: Twee honden slapen naast de dame. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Een klein meisje glimlacht in een kleurrijke gebreide hoed. Hypothesis: Het kleine meisje is gelukkig. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een klein meisje met een kleurrijke hoed op een kussen. Hypothesis: Een klein meisje rent door de woonkamer lachend Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een klein meisje met een kleurrijke hoed op een kussen. Hypothesis: Er is een klein meisje binnen. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', "Premise: Een klein meisje met een kleurrijke hoed op een kussen. Hypothesis: Een kind zit voor haar eerste verjaardag foto's Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.", 'Premise: Een klein meisje met een kleurrijke hoed op een kussen. Hypothesis: Een klein meisje draagt een kleurrijke hoed. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Een jongen gaat de glijbaan in. Hypothesis: Een jongen zit op een glijbaan. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een jongen gaat de glijbaan in. Hypothesis: Er is een jongen in het park. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een jongen gaat de glijbaan in. Hypothesis: Een jongen zit in een tent. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een grijze terriër loopt in een besneeuwd veld. Hypothesis: Een grijze hond die buiten loopt. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Een grijze terriër loopt in een besneeuwd veld. Hypothesis: Een grijze hond achter een eekhoorn aan. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# ['Premise: Eine Person auf einem Pferd springt über ein kaputtes Flugzeug. Hypothesis: Ein Mensch trainiert sein Pferd für einen Wettkampf. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Eine Person auf einem Pferd springt über ein kaputtes Flugzeug. Hypothesis: Eine Person ist im Diner und bestellt ein Omelett. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Eine Person auf einem Pferd springt über ein kaputtes Flugzeug. Hypothesis: Eine Person ist draußen, auf einem Pferd. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kinder lächeln und winken vor der Kamera Hypothesis: Sie lächeln ihre Eltern an Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kinder lächeln und winken vor der Kamera Hypothesis: Es gibt Kinder, die anwesend sind. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Kleines lachendes Kind mit blondem Haar, das an einem Tisch sitzt und einen grünen Schluckbecher hält. Hypothesis: Das Kind ist glücklich. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines lachendes Kind mit blondem Haar, das an einem Tisch sitzt und einen grünen Schluckbecher hält. Hypothesis: Ein Kind trinkt Apfelsaft. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines lachendes Kind mit blondem Haar, das an einem Tisch sitzt und einen grünen Schluckbecher hält. Hypothesis: Ein Kind wirft einen Wutanfall. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein kleiner Junge trinkt Milch und bekommt Milch über sein Gesicht und seinen Tisch. Hypothesis: das Kind hat Milch im Gesicht an einem Schultag Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein kleiner Junge trinkt Milch und bekommt Milch über sein Gesicht und seinen Tisch. Hypothesis: der Hund frisst Mäuse Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Zwei Frauen stehen unter einem Regenschirm. Hypothesis: zwei Jungs, die im Regen laufen Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein brauner Hund springt auf eine Frau, die einen braunen Rock trägt. Hypothesis: Der Hund sieht seinen Besitzer nach ein paar Stunden. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein brauner Hund springt auf eine Frau, die einen braunen Rock trägt. Hypothesis: Ein Hund ist freundlich. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein brauner Hund springt auf eine Frau, die einen braunen Rock trägt. Hypothesis: Ein Hund greift einen Mann an. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein Hund springt auf die Dame, während der andere weggeht. Hypothesis: Zwei Hunde schlafen neben der Dame. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Ein kleines Mädchen, das in einem bunten Strickhut lächelt. Hypothesis: Das kleine Mädchen ist glücklich Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines Mädchen trägt einen bunten Hut, während auf einem Kissen aufgeschlagen. Hypothesis: Ein kleines Mädchen läuft durch das Wohnzimmer lachend Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines Mädchen trägt einen bunten Hut, während auf einem Kissen aufgeschlagen. Hypothesis: Ein kleines Mädchen ist drin. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines Mädchen trägt einen bunten Hut, während auf einem Kissen aufgeschlagen. Hypothesis: Ein Kind sitzt für ihre ersten Geburtstagsfotos Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Kleines Mädchen trägt einen bunten Hut, während auf einem Kissen aufgeschlagen. Hypothesis: Ein kleines Mädchen trägt einen bunten Hut. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# ['Premise: Ein Junge geht die Rutsche runter. Hypothesis: Ein Junge ist auf einer Rutsche Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein Junge geht die Rutsche runter. Hypothesis: Ein Junge ist im Park Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein Junge geht die Rutsche runter. Hypothesis: Ein Junge ist in einem Zelt Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein grauer Terrier läuft in einem schneebedeckten Feld. Hypothesis: Ein grauer Hund, der draußen läuft. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.', 'Premise: Ein grauer Terrier läuft in einem schneebedeckten Feld. Hypothesis: Ein grauer Hund jagt ein Eichhörnchen im Freien. Please provide a justification for whether the hypothesis is entailed by the premise, contradicted by the premise, or if it cannot be determined.']
# Keys of tokenized dataset: ['explanation_1', 'language', 'input_ids', 'attention_mask', 'labels']

# %%
print (tokenized_dataset['train'].__dict__.keys())
# Out:
# dict_keys(['_info', '_split', '_indexes', '_data', '_indices', '_format_type', '_format_kwargs', '_format_columns', '_output_all_columns', '_fingerprint'])

# %%
from transformers import AutoModelForSeq2SeqLM

model_id = "google/flan-t5-base" # ryan: change to flan-t5-large later

# load model from the hub
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
import evaluate
import nltk
import numpy as np
from nltk.tokenize import sent_tokenize
nltk.download("punkt")

# Metric
metric = evaluate.load("rouge")
# metric = evaluate.load("accuracy")

# helper function to postprocess text
def postprocess_text(preds, labels):
    preds = [pred.strip() for pred in preds]
    labels = [label.strip() for label in labels]

    # rougeLSum expects newline after each sentence
    preds = ["\n".join(sent_tokenize(pred)) for pred in preds]
    labels = ["\n".join(sent_tokenize(label)) for label in labels]

    return preds, labels

def compute_metrics(eval_preds):
    preds, labels = eval_preds
    if isinstance(preds, tuple):
        preds = preds[0]
    decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    # Some simple post-processing
    decoded_preds, decoded_labels = postprocess_text(decoded_preds, decoded_labels)

    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    result = {k: round(v * 100, 4) for k, v in result.items()}
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in preds]
    result["gen_len"] = np.mean(prediction_lens)
    return result
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
from transformers import DataCollatorForSeq2Seq

# we want to ignore tokenizer pad token in the loss
label_pad_token_id = -100
# Data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=8
)

# %%
from huggingface_hub import HfFolder
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments

EPOCHS = 3

# Define training args
training_args = Seq2SeqTrainingArguments(
    output_dir="flant5base_4lang",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    fp16=False,
    learning_rate=5e-5,
    num_train_epochs=EPOCHS, 
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    # metric_for_best_model="overall_f1",
)

# Create Trainer instance
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    compute_metrics=compute_metrics,
)

# %%
print (trainer)
# Out:
# <transformers.trainer_seq2seq.Seq2SeqTrainer object at 0x7f75a67344f0>

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='7500' max='7500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7500/7500 1:11:09, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.667900</td>
#       <td>3.336565</td>
#       <td>22.535800</td>
#       <td>5.496000</td>
#       <td>21.267400</td>
#       <td>21.316000</td>
#       <td>17.753800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.475800</td>
#       <td>3.510611</td>
#       <td>20.198800</td>
#       <td>4.132700</td>
#       <td>19.224200</td>
#       <td>19.267500</td>
#       <td>18.150800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.430500</td>
#       <td>3.559953</td>
#       <td>19.847700</td>
#       <td>3.919900</td>
#       <td>18.906100</td>
#       <td>18.953700</td>
#       <td>18.018800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=7500, training_loss=1.6214600423177083, metrics={'train_runtime': 4272.6913, 'train_samples_per_second': 14.043, 'train_steps_per_second': 1.755, 'total_flos': 2.824624078848e+16, 'train_loss': 1.6214600423177083, 'epoch': 3.0})

# %%
# trainer.evaluate() # ignore this – not using rouge score
# Out:
#     <div>
#
#       <progress value='625' max='625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [625/625 06:25]
#     </div>
# {'eval_loss': 3.336564779281616,
#  'eval_rouge1': 22.5358,
#  'eval_rouge2': 5.496,
#  'eval_rougeL': 21.2674,
#  'eval_rougeLsum': 21.316,
#  'eval_gen_len': 17.7538,
#  'eval_runtime': 392.5387,
#  'eval_samples_per_second': 12.738,
#  'eval_steps_per_second': 1.592,
#  'epoch': 3.0}

# %% [markdown]
# Sample 2000 random instances from the 9.8K samples
#
# # ALREADY GENERATED –> DO NOT UNCOMMENT THIS

# %%
# final_test_data_de = read_translated_data(f"{DATAPATH}esnli_test_de.csv", 9824, "german")

# print (len(final_test_data_de))
# Out:
# 9824

# %%
# import random
# # random_sample_de_idx = np.random.randint(0, len(final_test_data_de), (2000)).tolist()
# random_sample_de_idx = random.sample(range(9824), k=2000)
# print (len(list(set(random_sample_de_idx))))
# random_sample_de = [final_test_data_de[i] for i in random_sample_de_idx]

# random_sample_de_df = pd.DataFrame(random_sample_de, columns=["premise", "hypothesis", "label", "explanation", "language"])
# random_sample_de_df.to_csv("drive/MyDrive/CS4248 Team 19/translated_data/final_random_2k_de.csv")
# Out:
# 2000

# %%
trainer.save_model("drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/")
tokenizer.save_pretrained("drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/")
# Out:
# ('drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/tokenizer_config.json',
#  'drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/special_tokens_map.json',
#  'drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/tokenizer.json')

# %%
# to ensure there's no loading issues –> doesn't do anything

model.from_pretrained("drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/")
tokenizer.from_pretrained("drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/")
# Out:
# T5TokenizerFast(name_or_path='drive/MyDrive/CS4248 Team 19/saved_models/flan-t5-base-4lang/', vocab_size=32100, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'additional_special_tokens': ['<extra_id_0>', '<extra_id_1>', '<extra_id_2>', '<extra_id_3>', '<extra_id_4>', '<extra_id_5>', '<extra_id_6>', '<extra_id_7>', '<extra_id_8>', '<extra_id_9>', '<extra_id_10>', '<extra_id_11>', '<extra_id_12>', '<extra_id_13>', '<extra_id_14>', '<extra_id_15>', '<extra_id_16>', '<extra_id_17>', '<extra_id_18>', '<extra_id_19>', '<extra_id_20>', '<extra_id_21>', '<extra_id_22>', '<extra_id_23>', '<extra_id_24>', '<extra_id_25>', '<extra_id_26>', '<extra_id_27>', '<extra_id_28>', '<extra_id_29>', '<extra_id_30>', '<extra_id_31>', '<extra_id_32>', '<extra_id_33>', '<extra_id_34>', '<extra_id_35>', '<extra_id_36>', '<extra_id_37>', '<extra_id_38>', '<extra_id_39>', '<extra_id_40>', '<extra_id_41>', '<extra_id_42>', '<extra_id_43>', '<extra_id_44>', '<extra_id_45>', '<extra_id_46>', '<extra_id_47>', '<extra_id_48>', '<extra_id_49>', '<extra_id_50>', '<extra_id_51>', '<extra_id_52>', '<extra_id_53>', '<extra_id_54>', '<extra_id_55>', '<extra_id_56>', '<extra_id_57>', '<extra_id_58>', '<extra_id_59>', '<extra_id_60>', '<extra_id_61>', '<extra_id_62>', '<extra_id_63>', '<extra_id_64>', '<extra_id_65>', '<extra_id_66>', '<extra_id_67>', '<extra_id_68>', '<extra_id_69>', '<extra_id_70>', '<extra_id_71>', '<extra_id_72>', '<extra_id_73>', '<extra_id_74>', '<extra_id_75>', '<extra_id_76>', '<extra_id_77>', '<extra_id_78>', '<extra_id_79>', '<extra_id_80>', '<extra_id_81>', '<extra_id_82>', '<extra_id_83>', '<extra_id_84>', '<extra_id_85>', '<extra_id_86>', '<extra_id_87>', '<extra_id_88>', '<extra_id_89>', '<extra_id_90>', '<extra_id_91>', '<extra_id_92>', '<extra_id_93>', '<extra_id_94>', '<extra_id_95>', '<extra_id_96>', '<extra_id_97>', '<extra_id_98>', '<extra_id_99>']})

# %% [markdown]
# From here on, we use the best finetuned model to evaluate on the German split.

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"

# !nvidia-smi
